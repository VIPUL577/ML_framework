# %%
from cuTen import cuten
import numpy as np
 
na = np.arange(0,1024,dtype = np.float32).reshape(16,64)
nb = np.arange(0,1024,dtype = np.float32).reshape(32,32)

a = cuten(na,dtype="float32")
b = cuten(nb,dtype = "float32")
# Out:
# the dtype is float32
# the dtype is float32

# %%
b+a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 b+a
#
# File ~/Documents/ML_framework/cuTen.py:63, in cuten.__add__(self, other)
#      61 if isinstance(other,cuten):
#      62     if self.shape != other.shape:
# ---> 63         raise ValueError(f"Should be of same shape for Elements Add one is of {self.shape} and {other.shape}")
#      64     c= cuten.ones_like(self)
#      65     seera_cuda.cuda_elemadd(self.main_ptr,other.main_ptr, c.main_ptr, self.size)
#
# ValueError: Should be of same shape for Elements Add one is of (32, 32) and (16, 64)

# %%
a
# Out:
# [1.000e+00 2.000e+00 3.000e+00 ... 1.021e+03 1.022e+03 1.023e+03]
# IT DOES WORK

# %%
at = (1,2,6,7)
bt = (1,2,6,7)

# %%
at == bt
# Out:
# True

# %%
c = a+b
# Out:
# the dtype is float32

# %%
c
# Out:
# [0.00000e+00 2.00000e+00 4.00000e+00 ... 2.04794e+05 2.04796e+05
#  2.04798e+05]
# IT DOES WORK
